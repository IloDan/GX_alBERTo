# %%
import pandas as pd

gxbert = pd.read_csv('../dataset/GX-BERT_tobuild37.csv', sep=',')

lizio = pd.read_csv('../dataset/Join_with_Lizio.csv', sep=',')

# %%
gxbert
# Out:
#                gene_id       gene_type genomic_strand  split    labels  \
# 0      ENSG00000121410  protein_coding              -  train  0.128766
# 1      ENSG00000148584  protein_coding              -  train -1.442332
# 2      ENSG00000175899  protein_coding              -  train  1.172033
# 3      ENSG00000166535  protein_coding              +  train -1.300226
# 4      ENSG00000128274  protein_coding              -  train  0.157178
# ...                ...             ...            ...    ...       ...
# 18123  ENSG00000166160  protein_coding              +  train -1.463212
# 18124  ENSG00000184033  protein_coding              -  train -1.463212
# 18125  ENSG00000126890  protein_coding              -  train -1.463212
# 18126  ENSG00000203870  protein_coding              -  train -1.463212
# 18127  ENSG00000182712  protein_coding              -  train  0.697807
#
#       gene_name
# 0          A1BG
# 1          A1CF
# 2           A2M
# 3         A2ML1
# 4        A4GALT
# ...         ...
# 18123   OPN1MW2
# 18124    CTAG1B
# 18125     CTAG2
# 18126     SMIM9
# 18127      CMC4
#
# [18128 rows x 6 columns]

# %%
lizio
# Out:
#        Unnamed: 0 gene_name   gene_stable_id             gene_id  \
# 0               0      A1BG  ENSG00000121410  ENSG00000121410.12
# 1               1      A1CF  ENSG00000148584  ENSG00000148584.15
# 2               2       A2M  ENSG00000175899  ENSG00000175899.15
# 3               3     A2ML1  ENSG00000166535  ENSG00000166535.20
# 4               4    A4GALT  ENSG00000128274  ENSG00000128274.17
# ...           ...       ...              ...                 ...
# 15615       15615    ZYG11A  ENSG00000203995  ENSG00000203995.10
# 15616       15616    ZYG11B  ENSG00000162378  ENSG00000162378.13
# 15617       15617       ZYX  ENSG00000159840  ENSG00000159840.16
# 15618       15618     ZZEF1  ENSG00000074755  ENSG00000074755.15
# 15619       15619      ZZZ3  ENSG00000036549  ENSG00000036549.13
#
#             gene_type        TSS genomic_strand chromosome_name
# 0      protein_coding   58347673              -           chr19
# 1      protein_coding   50885633              -           chr10
# 2      protein_coding    9115927              -           chr12
# 3      protein_coding    8822627              +           chr12
# 4      protein_coding   42720879              -           chr22
# ...               ...        ...            ...             ...
# 15615  protein_coding   52842770              +            chr1
# 15616  protein_coding   52726478              +            chr1
# 15617  protein_coding  143381361              +            chr7
# 15618  protein_coding    4143055              -           chr17
# 15619  protein_coding   77683457              -            chr1
#
# [15620 rows x 8 columns]

# %%
merged= pd.merge(gxbert, lizio, on='gene_name', how='inner')
merged
# Out:
#              gene_id_x     gene_type_x genomic_strand_x  split    labels  \
# 0      ENSG00000121410  protein_coding                -  train  0.128766
# 1      ENSG00000148584  protein_coding                -  train -1.442332
# 2      ENSG00000175899  protein_coding                -  train  1.172033
# 3      ENSG00000166535  protein_coding                +  train -1.300226
# 4      ENSG00000128274  protein_coding                -  train  0.157178
# ...                ...             ...              ...    ...       ...
# 15617  ENSG00000203995  protein_coding                +  train -0.984208
# 15618  ENSG00000162378  protein_coding                +  train  0.694430
# 15619  ENSG00000159840  protein_coding                +  train  1.646464
# 15620  ENSG00000074755  protein_coding                -  train  0.765210
# 15621  ENSG00000036549  protein_coding                -  train  0.672941
#
#       gene_name  Unnamed: 0   gene_stable_id           gene_id_y  \
# 0          A1BG           0  ENSG00000121410  ENSG00000121410.12
# 1          A1CF           1  ENSG00000148584  ENSG00000148584.15
# 2           A2M           2  ENSG00000175899  ENSG00000175899.15
# 3         A2ML1           3  ENSG00000166535  ENSG00000166535.20
# 4        A4GALT           4  ENSG00000128274  ENSG00000128274.17
# ...         ...         ...              ...                 ...
# 15617    ZYG11A       15615  ENSG00000203995  ENSG00000203995.10
# 15618    ZYG11B       15616  ENSG00000162378  ENSG00000162378.13
# 15619       ZYX       15617  ENSG00000159840  ENSG00000159840.16
# 15620     ZZEF1       15618  ENSG00000074755  ENSG00000074755.15
# 15621      ZZZ3       15619  ENSG00000036549  ENSG00000036549.13
#
#           gene_type_y        TSS genomic_strand_y chromosome_name
# 0      protein_coding   58347673                -           chr19
# 1      protein_coding   50885633                -           chr10
# 2      protein_coding    9115927                -           chr12
# 3      protein_coding    8822627                +           chr12
# 4      protein_coding   42720879                -           chr22
# ...               ...        ...              ...             ...
# 15617  protein_coding   52842770                +            chr1
# 15618  protein_coding   52726478                +            chr1
# 15619  protein_coding  143381361                +            chr7
# 15620  protein_coding    4143055                -           chr17
# 15621  protein_coding   77683457                -            chr1
#
# [15622 rows x 13 columns]

# %%
#prendi i geneid in gxbert che non sono in merged
gxbert_not_in_merged = gxbert[~gxbert.gene_id.isin(merged.gene_id_x)]
gxbert_not_in_merged
# Out:
#                gene_id       gene_type genomic_strand  split    labels  \
# 15620  ENSG00000179542  protein_coding              -  train -0.978198
# 15621  ENSG00000186092  protein_coding              +  train -1.463212
# 15622  ENSG00000187642  protein_coding              -   test -1.270874
# 15623  ENSG00000184163  protein_coding              -  train -0.580802
# 15624  ENSG00000127054  protein_coding              -  train  0.982652
# ...                ...             ...            ...    ...       ...
# 18123  ENSG00000166160  protein_coding              +  train -1.463212
# 18124  ENSG00000184033  protein_coding              -  train -1.463212
# 18125  ENSG00000126890  protein_coding              -  train -1.463212
# 18126  ENSG00000203870  protein_coding              -  train -1.463212
# 18127  ENSG00000182712  protein_coding              -  train  0.697807
#
#       gene_name
# 15620   SLITRK4
# 15621     OR4F5
# 15622     PERM1
# 15623  C1QTNF12
# 15624    INTS11
# ...         ...
# 18123   OPN1MW2
# 18124    CTAG1B
# 18125     CTAG2
# 18126     SMIM9
# 18127      CMC4
#
# [2508 rows x 6 columns]

# %%
ensemble = pd.read_csv('../dataset/ens37_mancanti.txt', sep='\t')
ensemble
# Out:
#                 gene_id          gene_id_v Transcript stable ID  \
# 0       ENSG00000261657  ENSG00000261657.1      ENST00000566782
# 1       ENSG00000261657  ENSG00000261657.1      ENST00000562780
# 2       ENSG00000261657  ENSG00000261657.1      ENST00000569579
# 3       ENSG00000261657  ENSG00000261657.1      ENST00000568242
# 4       ENSG00000261657  ENSG00000261657.1      ENST00000565530
# ...                 ...                ...                  ...
# 215399  ENSG00000263267  ENSG00000263267.1      ENST00000572372
# 215400  ENSG00000263267  ENSG00000263267.1      ENST00000572960
# 215401  ENSG00000263267  ENSG00000263267.1      ENST00000574432
# 215402  ENSG00000262336  ENSG00000262336.1      ENST00000577132
# 215403  ENSG00000262005  ENSG00000262005.1      ENST00000575999
#
#        Transcript stable ID version       TSS Chromosome/scaffold name  \
# 0                 ENST00000566782.1  66119285              HG991_PATCH
# 1                 ENST00000562780.1  66320895              HG991_PATCH
# 2                 ENST00000569579.1  66320895              HG991_PATCH
# 3                 ENST00000568242.1  66320895              HG991_PATCH
# 4                 ENST00000565530.1  66339287              HG991_PATCH
# ...                             ...       ...                      ...
# 215399            ENST00000572372.1    198858           HSCHR17_1_CTG1
# 215400            ENST00000572960.1    199139           HSCHR17_1_CTG1
# 215401            ENST00000574432.1    199766           HSCHR17_1_CTG1
# 215402            ENST00000577132.1    220262           HSCHR17_1_CTG1
# 215403            ENST00000575999.1    222361           HSCHR17_1_CTG1
#
#         strand  Transcript length (including UTRs and CDS)       gene_name  \
# 0            1                                        2673        SLC25A26
# 1            1                                        1096        SLC25A26
# 2            1                                        1840        SLC25A26
# 3            1                                        3405        SLC25A26
# 4            1                                         375        SLC25A26
# ...        ...                                         ...             ...
# 215399       1                                        2252  RP11-1260E13.4
# 215400       1                                         555  RP11-1260E13.4
# 215401       1                                         503  RP11-1260E13.4
# 215402       1                                         748  RP11-1260E13.2
# 215403       1                                         913  RP11-1260E13.3
#
#             Source of gene name             Gene type
# 0                   HGNC Symbol        protein_coding
# 1                   HGNC Symbol        protein_coding
# 2                   HGNC Symbol        protein_coding
# 3                   HGNC Symbol        protein_coding
# 4                   HGNC Symbol        protein_coding
# ...                         ...                   ...
# 215399  Clone-based (Vega) gene  processed_transcript
# 215400  Clone-based (Vega) gene  processed_transcript
# 215401  Clone-based (Vega) gene  processed_transcript
# 215402  Clone-based (Vega) gene             antisense
# 215403  Clone-based (Vega) gene             antisense
#
# [215404 rows x 11 columns]

# %%
#merge con ensemble
merged_ensemble= pd.merge(gxbert_not_in_merged, ensemble, on='gene_id', how='inner')
merged_ensemble
# Out:
#                gene_id       gene_type genomic_strand  split    labels  \
# 0      ENSG00000179542  protein_coding              -  train -0.978198
# 1      ENSG00000179542  protein_coding              -  train -0.978198
# 2      ENSG00000179542  protein_coding              -  train -0.978198
# 3      ENSG00000186092  protein_coding              +  train -1.463212
# 4      ENSG00000187642  protein_coding              -   test -1.270874
# ...                ...             ...            ...    ...       ...
# 14230  ENSG00000203870  protein_coding              -  train -1.463212
# 14231  ENSG00000203870  protein_coding              -  train -1.463212
# 14232  ENSG00000203870  protein_coding              -  train -1.463212
# 14233  ENSG00000182712  protein_coding              -  train  0.697807
# 14234  ENSG00000182712  protein_coding              -  train  0.697807
#
#       gene_name_x           gene_id_v Transcript stable ID  \
# 0         SLITRK4  ENSG00000179542.11      ENST00000338017
# 1         SLITRK4  ENSG00000179542.11      ENST00000356928
# 2         SLITRK4  ENSG00000179542.11      ENST00000381779
# 3           OR4F5   ENSG00000186092.4      ENST00000335137
# 4           PERM1   ENSG00000187642.5      ENST00000341290
# ...           ...                 ...                  ...
# 14230       SMIM9   ENSG00000203870.5      ENST00000369529
# 14231       SMIM9   ENSG00000203870.5      ENST00000578244
# 14232       SMIM9   ENSG00000203870.5      ENST00000478043
# 14233        CMC4  ENSG00000182712.11      ENST00000369484
# 14234        CMC4  ENSG00000182712.11      ENST00000369479
#
#       Transcript stable ID version        TSS Chromosome/scaffold name  \
# 0                ENST00000338017.4  142723019                        X
# 1                ENST00000356928.1  142723596                        X
# 2                ENST00000381779.4  142722319                        X
# 3                ENST00000335137.3      69091                        1
# 4                ENST00000341290.2     917473                        1
# ...                            ...        ...                      ...
# 14230            ENST00000369529.1  154060946                        X
# 14231            ENST00000578244.1  154055733                        X
# 14232            ENST00000478043.1  154062937                        X
# 14233            ENST00000369484.3  154299637                        X
# 14234            ENST00000369479.1  154293643                        X
#
#        strand  Transcript length (including UTRs and CDS) gene_name_y  \
# 0          -1                                        3357     SLITRK4
# 1          -1                                        3074     SLITRK4
# 2          -1                                        8555     SLITRK4
# 3           1                                         918       OR4F5
# 4          -1                                        3035    C1orf170
# ...       ...                                         ...         ...
# 14230      -1                                         904       SMIM9
# 14231      -1                                         222       SMIM9
# 14232      -1                                         593       SMIM9
# 14233      -1                                        1107        CMC4
# 14234      -1                                         864        CMC4
#
#       Source of gene name       Gene type
# 0             HGNC Symbol  protein_coding
# 1             HGNC Symbol  protein_coding
# 2             HGNC Symbol  protein_coding
# 3             HGNC Symbol  protein_coding
# 4             HGNC Symbol  protein_coding
# ...                   ...             ...
# 14230         HGNC Symbol  protein_coding
# 14231         HGNC Symbol  protein_coding
# 14232         HGNC Symbol  protein_coding
# 14233         HGNC Symbol  protein_coding
# 14234         HGNC Symbol  protein_coding
#
# [14235 rows x 16 columns]

# %%
df4 = merged_ensemble.loc[merged_ensemble.groupby("gene_id")["Transcript length (including UTRs and CDS)"].idxmax()]
df4
# Out:
#                gene_id       gene_type genomic_strand  split    labels  \
# 203    ENSG00000001460  protein_coding              -  train -0.114932
# 5252   ENSG00000002726  protein_coding              +  train -1.409453
# 1472   ENSG00000003509  protein_coding              +  train  0.547833
# 5009   ENSG00000004766  protein_coding              +  train  0.274832
# 3112   ENSG00000005059  protein_coding              +  train  0.495584
# ...                ...             ...            ...    ...       ...
# 11751  ENSG00000259120  protein_coding              +   test -1.050895
# 11256  ENSG00000259224  protein_coding              +  train -1.392807
# 5740   ENSG00000259305  protein_coding              -  train  0.848319
# 13190  ENSG00000259399  protein_coding              +  train  1.680397
# 8040   ENSG00000259571  protein_coding              -  valid -1.388735
#
#         gene_name_x           gene_id_v Transcript stable ID  \
# 203           STPG1  ENSG00000001460.13      ENST00000468303
# 5252           AOC1  ENSG00000002726.15      ENST00000493429
# 1472        NDUFAF7  ENSG00000003509.11      ENST00000474154
# 5009          VPS50  ENSG00000004766.11      ENST00000544910
# 3112           MCUB  ENSG00000005059.11      ENST00000394650
# ...             ...                 ...                  ...
# 11751         SMIM6   ENSG00000259120.2      ENST00000579469
# 11256       SLC35G6   ENSG00000259224.1      ENST00000412468
# 5740   ZHX1-C8orf76   ENSG00000259305.1      ENST00000357082
# 13190  TGIF2-RAB5IF   ENSG00000259399.1      ENST00000558530
# 8040           BLID   ENSG00000259571.1      ENST00000560104
#
#       Transcript stable ID version        TSS Chromosome/scaffold name  \
# 203              ENST00000468303.1   24743424                        1
# 5252             ENST00000493429.1  150521715                        7
# 1472             ENST00000474154.1   37458806                        2
# 5009             ENST00000544910.1   92861679                        7
# 3112             ENST00000394650.4  110481361                        4
# ...                            ...        ...                      ...
# 11751            ENST00000579469.1   73642517                       17
# 11256            ENST00000412468.2    7384721                       17
# 5740             ENST00000357082.4  124279627                        8
# 13190            ENST00000558530.1   35202956                       20
# 8040             ENST00000560104.1  121986923                       11
#
#        strand  Transcript length (including UTRs and CDS)     gene_name_y  \
# 203        -1                                        6016           STPG1
# 5252        1                                        3135            AOC1
# 1472        1                                        2974         NDUFAF7
# 5009        1                                        3614         CCDC132
# 3112        1                                        2270        CCDC109B
# ...       ...                                         ...             ...
# 11751       1                                         957           SMIM6
# 11256       1                                        1195         SLC35G6
# 5740       -1                                        1255    ZHX1-C8ORF76
# 13190       1                                         918  TGIF2-C20orf24
# 8040       -1                                         862            BLID
#
#       Source of gene name       Gene type
# 203           HGNC Symbol  protein_coding
# 5252          HGNC Symbol  protein_coding
# 1472          HGNC Symbol  protein_coding
# 5009          HGNC Symbol  protein_coding
# 3112          HGNC Symbol  protein_coding
# ...                   ...             ...
# 11751         HGNC Symbol  protein_coding
# 11256         HGNC Symbol  protein_coding
# 5740          HGNC Symbol  protein_coding
# 13190         HGNC Symbol  protein_coding
# 8040          HGNC Symbol  protein_coding
#
# [2508 rows x 16 columns]

# %%
order=df4.columns.tolist()
df6=df4

# %%
#aggiungi chr di fianco a chromosome_name
df6['chromosome_name'] = df6['chromosome_name'].apply(lambda x: 'chr'+str(x))
df6
# Out:
#                gene_id       gene_type  split    labels     gene_name  \
# 203    ENSG00000001460  protein_coding  train -0.114932         STPG1
# 5252   ENSG00000002726  protein_coding  train -1.409453          AOC1
# 1472   ENSG00000003509  protein_coding  train  0.547833       NDUFAF7
# 5009   ENSG00000004766  protein_coding  train  0.274832         VPS50
# 3112   ENSG00000005059  protein_coding  train  0.495584          MCUB
# ...                ...             ...    ...       ...           ...
# 11751  ENSG00000259120  protein_coding   test -1.050895         SMIM6
# 11256  ENSG00000259224  protein_coding  train -1.392807       SLC35G6
# 5740   ENSG00000259305  protein_coding  train  0.848319  ZHX1-C8orf76
# 13190  ENSG00000259399  protein_coding  train  1.680397  TGIF2-RAB5IF
# 8040   ENSG00000259571  protein_coding  valid -1.388735          BLID
#
#              TSS chromosome_name strand
# 203     24743424            chr1      -
# 5252   150521715            chr7      +
# 1472    37458806            chr2      +
# 5009    92861679            chr7      +
# 3112   110481361            chr4      +
# ...          ...             ...    ...
# 11751   73642517           chr17      +
# 11256    7384721           chr17      +
# 5740   124279627            chr8      -
# 13190   35202956           chr20      +
# 8040   121986923           chr11      -
#
# [2508 rows x 8 columns]

# %%
merged=merged[order]
merged
# Out:
#                gene_id       gene_type  split    labels gene_name        TSS  \
# 0      ENSG00000121410  protein_coding  train  0.128766      A1BG   58347673
# 1      ENSG00000148584  protein_coding  train -1.442332      A1CF   50885633
# 2      ENSG00000175899  protein_coding  train  1.172033       A2M    9115927
# 3      ENSG00000166535  protein_coding  train -1.300226     A2ML1    8822627
# 4      ENSG00000128274  protein_coding  train  0.157178    A4GALT   42720879
# ...                ...             ...    ...       ...       ...        ...
# 15617  ENSG00000203995  protein_coding  train -0.984208    ZYG11A   52842770
# 15618  ENSG00000162378  protein_coding  train  0.694430    ZYG11B   52726478
# 15619  ENSG00000159840  protein_coding  train  1.646464       ZYX  143381361
# 15620  ENSG00000074755  protein_coding  train  0.765210     ZZEF1    4143055
# 15621  ENSG00000036549  protein_coding  train  0.672941      ZZZ3   77683457
#
#       chromosome_name strand
# 0               chr19      -
# 1               chr10      -
# 2               chr12      -
# 3               chr12      +
# 4               chr22      -
# ...               ...    ...
# 15617            chr1      +
# 15618            chr1      +
# 15619            chr7      +
# 15620           chr17      -
# 15621            chr1      -
#
# [15622 rows x 8 columns]

# %%
#concatena i due dataframe
result = pd.concat([merged, df6])
result
# Out:
#                gene_id       gene_type  split    labels     gene_name  \
# 0      ENSG00000121410  protein_coding  train  0.128766          A1BG
# 1      ENSG00000148584  protein_coding  train -1.442332          A1CF
# 2      ENSG00000175899  protein_coding  train  1.172033           A2M
# 3      ENSG00000166535  protein_coding  train -1.300226         A2ML1
# 4      ENSG00000128274  protein_coding  train  0.157178        A4GALT
# ...                ...             ...    ...       ...           ...
# 11751  ENSG00000259120  protein_coding   test -1.050895         SMIM6
# 11256  ENSG00000259224  protein_coding  train -1.392807       SLC35G6
# 5740   ENSG00000259305  protein_coding  train  0.848319  ZHX1-C8orf76
# 13190  ENSG00000259399  protein_coding  train  1.680397  TGIF2-RAB5IF
# 8040   ENSG00000259571  protein_coding  valid -1.388735          BLID
#
#              TSS chromosome_name strand
# 0       58347673           chr19      -
# 1       50885633           chr10      -
# 2        9115927           chr12      -
# 3        8822627           chr12      +
# 4       42720879           chr22      -
# ...          ...             ...    ...
# 11751   73642517           chr17      +
# 11256    7384721           chr17      +
# 5740   124279627            chr8      -
# 13190   35202956           chr20      +
# 8040   121986923           chr11      -
#
# [18130 rows x 8 columns]

# %%
result.to_csv('../dataset/FINITOPD.csv', index=False)
