# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# convert te list in np array
seq = [0.548, 0.565, 0.569, 0.568, 0.578, 0.551, 0.568, 0.579, 0.548, 0.570]
seq = np.array(seq)
metsum = [0.567, 0.572, 0.565, 0.570, 0.568, 0.566, 0.569, 0.569, 0.582]
metsum = np.array(metsum)
seq_met = [0.565, 0.571, 0.569, 0.564 ,0.551, 0.573, 0.576, 0.571]
seq_met = np.array(seq_met)

# %%
#boxplot delle tre sequenze
plt.boxplot([seq, metsum, seq_met], labels=['DNA Seq only', 'with Met feature', 'with methylation vector'])
plt.ylabel('R^2 score')
plt.title('R^2 score for the three configuration of the model')
plt.show()
